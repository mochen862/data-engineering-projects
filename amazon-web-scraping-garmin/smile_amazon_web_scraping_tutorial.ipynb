# %% [markdown]
# # smile.amazon.co.uk web scraping - Garmin

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
URL = 'https://smile.amazon.co.uk/s?k=garmin&crid=L7ZKSQ2SXQEU&sprefix=garm%2Caps%2C167&ref=nb_sb_noss_2'

# %% [markdown]
# - if you don't know your user-agent go to https://www.whatismybrowser.com/ to find it
# - or you find a bunch of user agents here https://developers.whatismybrowser.com/useragents/explore/software_type_specific/web-browser/2

# %%
# headers for request
HEADERS = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36',
          'Accept-Language': 'en-US, en;q=0.5'}

# %%
# HTTP request
webpage = requests.get(URL, headers=HEADERS)
webpage
# Out:
# <Response [200]>

# %%
type(webpage.content)
# Out:
# bytes

# %%
# soup object containig all data
soup = BeautifulSoup(webpage.content, 'html.parser')

# %%
# fetch links as list of tag objects
links = soup.find_all("a", attrs={'class':'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'})

# %%
link = links[0]. get('href')

# %%
link
# Out:
# '/sspa/click?ie=UTF8&spc=MTo5NzUzNjQ4NzQ3OTc5NDU6MTY2ODcxNDk2NDpzcF9hdGY6MjAwODI1MjMxNTI3OTg6OjA6Og&url=%2FGarmin-Vivoactive-Smartwatch-Built-Sports%2Fdp%2FB085S7ZKWV%2Fref%3Dsr_1_1_sspa%3Fcrid%3DL7ZKSQ2SXQEU%26keywords%3Dgarmin%26pldnSite%3D1%26qid%3D1668714964%26sprefix%3Dgarm%252Caps%252C167%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1'

# %%
# storing the link in product_list
product_list = 'https://smile.amazon.co.uk' + link

# %%
product_list
# Out:
# 'https://smile.amazon.co.uk/sspa/click?ie=UTF8&spc=MTo5NzUzNjQ4NzQ3OTc5NDU6MTY2ODcxNDk2NDpzcF9hdGY6MjAwODI1MjMxNTI3OTg6OjA6Og&url=%2FGarmin-Vivoactive-Smartwatch-Built-Sports%2Fdp%2FB085S7ZKWV%2Fref%3Dsr_1_1_sspa%3Fcrid%3DL7ZKSQ2SXQEU%26keywords%3Dgarmin%26pldnSite%3D1%26qid%3D1668714964%26sprefix%3Dgarm%252Caps%252C167%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1'

# %%
new_webpage = requests.get(product_list, headers=HEADERS)

# %%
new_webpage
# Out:
# <Response [200]>

# %%
# soup object containing product data
new_soup = BeautifulSoup(new_webpage.content, 'html.parser')

# %%
# finding the title
new_soup.find('span', attrs={'id':'productTitle'}).text.strip()
# Out:
# 'Garmin Vivoactive 3 GPS Smartwatch with Built-in Sports Apps and Wrist Heart Rate - Rose Gold/White (Renewed)'

# %%
# finding the price
new_soup.find('span', attrs={'class':'a-price a-text-price a-size-medium apexPriceToPay'}).find('span', attrs={'class':'a-offscreen'}).text.strip()
# Out:
# '£139.95'

# %%
# extracting the rating
new_soup.find('span', attrs={'class':'a-icon-alt'}).text.strip()
# Out:
# '4.3 out of 5 stars'
